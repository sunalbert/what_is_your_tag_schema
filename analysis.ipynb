# %% [markdown]
# - https://www.clips.uantwerpen.be/conll2003/
# ```
#    U.N.         NNP  I-NP  I-ORG
#    official     NN   I-NP  O
#    Ekeus        NNP  I-NP  I-PER
#    heads        VBZ  I-VP  O
#    for          IN   I-PP  O
#    Baghdad      NNP  I-NP  I-LOC
#    .            .    O     O
# ```
#
# - https://www.clips.uantwerpen.be/conll2000/chunking/
# ```
#    He        PRP  B-NP
#    reckons   VBZ  B-VP
#    the       DT   B-NP
#    current   JJ   I-NP
#    account   NN   I-NP
#    deficit   NN   I-NP
#    will      MD   B-VP
#    narrow    VB   I-VP
#    to        TO   B-PP
#    only      RB   B-NP
#    #         #    I-NP
#    1.8       CD   I-NP
#    billion   CD   I-NP
#    in        IN   B-PP
#    September NNP  B-NP
#    .         .    O
# ```

# %%
import os
import re

def load_data(file_path,label_column_id=-1,is_test=False):
    '''
    file_path:文件路径
    label_column_id:当前考虑的标签列,取值为-1,0,1,2...,默认-1
    '''
    with open(file_path, "r", encoding="utf8") as f:
        raw_data = f.read()
    if  is_test:
        return raw_data.split("\n\n")
    else:
        data = []
        labels = []
        for raw in raw_data.split("\n\n"):
            sent = []
            raw = raw.strip()
            if raw == '':
                continue
            for line in raw.split("\n"):
                word,*tags = re.split(r'\s+',line)
                if tags==[]:
                    print(line)
                    raise Exception('Data format is not right!')
                sent.append((word, tags[label_column_id]))
                labels.append(tags[label_column_id])
            if sent!=[]:
                data.append(sent)
        return data,labels

# %%
from collections import Counter

def analysis(namespace):
    print('Namespace = {}'.format(namespace.folder))
    print('tag_columns = {}'.format(','.join(namespace.tag_columns)))
    print('Result')
    print('-'*50)
    for file in os.listdir(namespace.folder):
        if file.find('test')!=-1:
            file_path = os.path.join(namespace.folder,file)
            print('File = {}'.format(file_path))
            data = load_data(file_path,is_test=True)
            print('Sentences = {}'.format(len(data)))
        else:
            file_path = os.path.join(namespace.folder,file)
            print('File = {}'.format(file_path))
            for i in range(len(namespace.tag_columns)):
                print('Column = {}'.format(namespace.tag_columns[i]))
                data,labels = load_data(file_path,label_column_id=i)
                print('Sentences = {} '.format(len(data)))
                print('Tags = {}'.format(','.join(set(labels))))
                if namespace.tag_columns[i]=='NER' or namespace.tag_columns[i]=='NP':
                    tag_schema = Counter([t.split('-')[0] for t in labels if t!='-X-'])
                    tags = Counter([t.split('-')[-1] for t in labels if t!='-X-'])
                    print('Tag schema')
                    print(tag_schema.most_common())
                    print('Tags')
                    print(tags.most_common())
                print()
    print('-'*50)

# %%
from argparse import Namespace

def main():
    coll2003 = Namespace(
        folder = 'conll_2003',
        tag_columns = ['POS','NP','NER']
    )
    coll2000 = Namespace(
        folder = 'conll_2000',
        tag_columns = ['POS','NP']
    )
    analysis(coll2000)
    analysis(coll2003)

# %%
main()
# Out:
# Namespace = conll_2000
# tag_columns = POS,NP
# Result
# --------------------------------------------------
# File = conll_2000/test.txt
# Sentences = 2013
# File = conll_2000/train.txt
# Column = POS
# Sentences = 8936
# Tags = RP,CC,RB,MD,WDT,TO,PDT,RBS,JJ,UH,JJR,),WP,VBD,CD,:,WRB,VB,,,VBG,NNP,VBP,(,JJS,VBZ,NNS,RBR,IN,PRP$,POS,$,FW,NN,VBN,WP$,.,DT,SYM,NNPS,#,PRP,'',``,EX
#
# Column = NP
# Sentences = 8936
# Tags = I-PRT,B-UCP,I-INTJ,I-CONJP,B-INTJ,I-ADJP,I-UCP,B-LST,I-NP,B-ADJP,I-ADVP,B-CONJP,I-VP,O,B-NP,I-SBAR,B-SBAR,B-PRT,B-ADVP,B-PP,I-PP,B-VP
# Tag schema
# [('B', 106978), ('I', 76847), ('O', 27902)]
# Tags
# [('NP', 118388), ('VP', 33470), ('O', 27902), ('PP', 21572), ('ADVP', 4670), ('ADJP', 2703), ('SBAR', 2277), ('PRT', 558), ('CONJP', 129), ('INTJ', 40), ('LST', 10), ('UCP', 8)]
#
# --------------------------------------------------
# Namespace = conll_2003
# tag_columns = POS,NP,NER
# Result
# --------------------------------------------------
# File = conll_2003/dev.txt
# Column = POS
# Sentences = 3466
# Tags = RP,CC,RB,NN|SYM,MD,WDT,TO,PDT,RBS,LS,JJ,UH,:,),WP,VBD,CD,JJR,WRB,VB,,,VBG,NNP,VBP,(,JJS,VBZ,NNS,RBR,IN,PRP$,POS,$,",NN,FW,VBN,WP$,.,DT,SYM,-X-,NNPS,PRP,'',EX
#
# Column = NP
# Sentences = 3466
# Tags = I-PRT,B-LST,I-NP,B-ADJP,B-ADVP,B-PP,-X-,I-ADVP,B-CONJP,B-NP,B-PRT,I-PP,I-SBAR,I-CONJP,I-ADJP,B-INTJ,I-VP,O,B-SBAR,B-VP
# Tag schema
# [('B', 25737), ('I', 18653), ('O', 6972)]
# Tags
# [('NP', 30997), ('O', 6972), ('VP', 6867), ('PP', 4901), ('ADVP', 689), ('SBAR', 372), ('ADJP', 358), ('PRT', 149), ('INTJ', 31), ('CONJP', 23), ('LST', 3)]
#
# Column = NER
# Sentences = 3466
# Tags = B-PER,I-LOC,I-PER,B-MISC,I-ORG,I-MISC,O,B-ORG,B-LOC
# Tag schema
# [('O', 42975), ('B', 5942), ('I', 2661)]
# Tags
# [('O', 42975), ('PER', 3149), ('LOC', 2094), ('ORG', 2092), ('MISC', 1268)]
#
# File = conll_2003/test.txt
# Sentences = 3684
# File = conll_2003/train.txt
# Column = POS
# Sentences = 14987
# Tags = RP,CC,RB,NN|SYM,MD,WDT,TO,LS,RBS,JJ,UH,JJR,),:,VBD,CD,WP,WRB,VB,,,NNP,(,VBP,VBG,JJS,VBZ,NNS,RBR,'',IN,",POS,FW,PRP$,NN,$,VBN,WP$,.,DT,SYM,-X-,NNPS,PRP,PDT,EX
#
# Column = NP
# Sentences = 14987
# Tags = I-INTJ,I-CONJP,B-INTJ,I-ADJP,B-LST,I-NP,B-ADJP,B-CONJP,I-ADVP,I-VP,O,B-NP,I-SBAR,B-SBAR,B-PRT,I-LST,B-ADVP,B-PP,-X-,I-PP,B-VP
# Tag schema
# [('B', 99997), ('I', 75978), ('O', 27646)]
# Tags
# [('NP', 124032), ('O', 27646), ('VP', 26865), ('PP', 18946), ('ADVP', 2775), ('ADJP', 1376), ('SBAR', 1288), ('PRT', 527), ('CONJP', 70), ('INTJ', 60), ('LST', 36)]
#
# Column = NER
# Sentences = 14987
# Tags = B-PER,I-LOC,I-PER,B-MISC,I-ORG,I-MISC,O,B-ORG,B-LOC
# Tag schema
# [('O', 170524), ('B', 23499), ('I', 10544)]
# Tags
# [('O', 170524), ('PER', 11128), ('ORG', 10025), ('LOC', 8297), ('MISC', 4593)]
#
# --------------------------------------------------
